# %%
from scripture.functions import *
from scripture.NLP_Pipe import *
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
import pickle
from sklearn.naive_bayes import MultinomialNB

# %%
ads = get_ads_frame()
ads = ads[~ads['ad_copy'].isna()]

# %%
tf, count, tf_mat, count_mat, word_freq = nlp_pipe(ads)

# %%
count_mat.shape
# Out:
# (3477, 11174)

# %%
word_freq
# Out:
# [('black', 1713),
#  ('police', 851),
#  ('people', 647),
#  ('com', 514),
#  ('join', 460),
#  ('stop', 398),
#  ('like', 364),
#  ('free', 357),
#  ('man', 357),
#  ('america', 346),
#  ('community', 332),
#  ('https', 331),
#  ('matters', 324),
#  ('american', 320),
#  ('don', 309),
#  ('just', 272),
#  ('www', 269),
#  ('white', 262),
#  ('bm', 258),
#  ('year', 246),
#  ('follow', 229),
#  ('facebook', 224),
#  ('officer', 221),
#  ('video', 218),
#  ('life', 215),
#  ('blackmattersus', 215),
#  ('old', 212),
#  ('new', 211),
#  ('cops', 205),
#  ('make', 204),
#  ('support', 204),
#  ('want', 202),
#  ('officers', 199),
#  ('time', 196),
#  ('racism', 191),
#  ('african', 190),
#  ('school', 189),
#  ('country', 187),
#  ('day', 184),
#  ('said', 184),
#  ('let', 181),
#  ('shot', 179),
#  ('lives', 175),
#  ('know', 174),
#  ('news', 169),
#  ('years', 168),
#  ('justice', 166),
#  ('brutality', 165),
#  ('trump', 162),
#  ('cop', 161),
#  ('2nd', 160),
#  ('stand', 154),
#  ('rights', 153),
#  ('twitter', 150),
#  ('americans', 149),
#  ('need', 148),
#  ('united', 145),
#  ('help', 145),
#  ('government', 143),
#  ('family', 140),
#  ('world', 138),
#  ('defense', 138),
#  ('music', 134),
#  ('channel', 134),
#  ('self', 133),
#  ('death', 126),
#  ('think', 125),
#  ('matter', 125),
#  ('bring', 125),
#  ('friends', 124),
#  ('feel', 123),
#  ('way', 122),
#  ('killed', 121),
#  ('state', 121),
#  ('right', 117),
#  ('home', 115),
#  ('president', 114),
#  ('good', 114),
#  ('veterans', 114),
#  ('instagram', 114),
#  ('history', 113),
#  ('war', 113),
#  ('online', 111),
#  ('love', 109),
#  ('guns', 109),
#  ('safe', 108),
#  ('musicfb', 107),
#  ('today', 106),
#  ('children', 106),
#  ('gun', 106),
#  ('woman', 105),
#  ('law', 104),
#  ('students', 104),
#  ('come', 103),
#  ('event', 103),
#  ('proud', 102),
#  ('hillary', 101),
#  ('women', 100),
#  ('city', 100),
#  ('shooting', 99),
#  ('fight', 98),
#  ('clinton', 98),
#  ('blacklivesmatter', 97),
#  ('care', 96),
#  ('didn', 96),
#  ('states', 95),
#  ('amendment', 95),
#  ('did', 94),
#  ('usa', 94),
#  ('live', 94),
#  ('education', 94),
#  ('facemusic', 93),
#  ('hate', 92),
#  ('obama', 92),
#  ('click', 92),
#  ('believe', 92),
#  ('won', 92),
#  ('really', 91),
#  ('share', 90),
#  ('men', 90),
#  ('say', 90),
#  ('kids', 90),
#  ('info', 90),
#  ('change', 89),
#  ('nation', 89),
#  ('racist', 89),
#  ('innocent', 89),
#  ('player', 89),
#  ('texas', 88),
#  ('according', 87),
#  ('young', 86),
#  ('racial', 86),
#  ('youtube', 86),
#  ('national', 85),
#  ('illegal', 84),
#  ('great', 84),
#  ('power', 83),
#  ('protest', 83),
#  ('real', 82),
#  ('patriots', 80),
#  ('stay', 80),
#  ('beautiful', 80),
#  ('rally', 79),
#  ('peace', 79),
#  ('story', 78),
#  ('protect', 78),
#  ('truth', 77),
#  ('basis', 77),
#  ('repost', 77),
#  ('williams', 76),
#  ('remember', 75),
#  ('child', 75),
#  ('supporters', 75),
#  ('refugees', 75),
#  ('subscribe', 75),
#  ('money', 74),
#  ('teen', 74),
#  ('place', 74),
#  ('high', 74),
#  ('class', 73),
#  ('student', 73),
#  ('page', 72),
#  ('shows', 72),
#  ('gay', 72),
#  ('http', 71),
#  ('fact', 70),
#  ('violence', 70),
#  ('melanin', 70),
#  ('social', 69),
#  ('incident', 69),
#  ('south', 68),
#  ('learn', 67),
#  ('party', 67),
#  ('organized', 67),
#  ('muslims', 66),
#  ('flag', 66),
#  ('ur', 66),
#  ('listen', 65),
#  ('girl', 65),
#  ('donation', 65),
#  ('military', 64),
#  ('lgbt', 64),
#  ('group', 64),
#  ('ucsbzpcwudpvdcr6vraocdtg', 64),
#  ('000', 63),
#  ('face', 63),
#  ('prison', 63),
#  ('tell', 62),
#  ('mother', 62),
#  ('15', 61),
#  ('understand', 61),
#  ('blackandproud', 61),
#  ('members', 60),
#  ('public', 60),
#  ('going', 60),
#  ('better', 59),
#  ('ll', 59),
#  ('media', 58),
#  ('doesn', 58),
#  ('voice', 58),
#  ('does', 58),
#  ('department', 58),
#  ('lovers', 58),
#  ('second', 57),
#  ('job', 57),
#  ('kalvin', 57),
#  ('attention', 56),
#  ('called', 56),
#  ('killing', 56),
#  ('county', 56),
#  ('citizens', 55),
#  ('blacks', 55),
#  ('crime', 55),
#  ('defendthe', 55),
#  ('arrest', 54),
#  ('heart', 54),
#  ('sure', 54),
#  ('immigration', 54),
#  ('god', 54),
#  ('died', 54),
#  ('king', 54),
#  ('race', 53),
#  ('freedom', 53),
#  ('york', 53),
#  ('schools', 53),
#  ('muslim', 53),
#  ('st', 53),
#  ('jump', 53),
#  ('unite4justice', 53),
#  ('blackexcellence', 53),
#  ('force', 52),
#  ('society', 52),
#  ('best', 52),
#  ('times', 52),
#  ('took', 52),
#  ('got', 52),
#  ('car', 52),
#  ('download', 52),
#  ('browser', 52),
#  ('use', 51),
#  ('thing', 51),
#  ('civil', 51),
#  ('africanamerican', 51),
#  ('syria', 51),
#  ('blackpride', 51),
#  ('case', 50),
#  ('videos', 50),
#  ('church', 50),
#  ('work', 50),
#  ('parents', 49),
#  ('important', 49),
#  ('vote', 49),
#  ('jail', 49),
#  ('october', 49),
#  ('williams8kalvin', 49),
#  ('reason', 48),
#  ('things', 48),
#  ('anti', 48),
#  ('transgender', 48),
#  ('bit', 48),
#  ('march', 48),
#  ('problem', 48),
#  ('immigrants', 47),
#  ('end', 47),
#  ('injustice', 47),
#  ('absolutely', 47),
#  ('21', 47),
#  ('watch', 47),
#  ('woke', 47),
#  ('university', 46),
#  ('issues', 46),
#  ('forget', 46),
#  ('ve', 46),
#  ('away', 46),
#  ('person', 46),
#  ('confederate', 46),
#  ('movement', 46),
#  ('legal', 46),
#  ('business', 46),
#  ('tamir', 46),
#  ('bad', 45),
#  ('look', 45),
#  ('middle', 45),
#  ('arrested', 45),
#  ('events', 45),
#  ('memory', 45),
#  ('april', 45),
#  ('jerome', 45),
#  ('discrimination', 44),
#  ('honor', 44),
#  ('10', 44),
#  ('doing', 44),
#  ('owned', 44),
#  ('hard', 44),
#  ('chicago', 44),
#  ('viral', 44),
#  ('words', 43),
#  ('color', 43),
#  ('long', 43),
#  ('speak', 43),
#  ('situation', 43),
#  ('example', 43),
#  ('chief', 42),
#  ('victims', 42),
#  ('makes', 42),
#  ('12', 42),
#  ('mr', 42),
#  ('11', 42),
#  ('opportunity', 42),
#  ('rice', 42),
#  ('strong', 41),
#  ('dead', 41),
#  ('federal', 41),
#  ('22', 41),
#  ('garner', 41),
#  ('save', 41),
#  ('anniversary', 41),
#  ('borders', 41),
#  ('trying', 40),
#  ('days', 40),
#  ('despite', 40),
#  ('taking', 40),
#  ('sign', 40),
#  ('having', 40),
#  ('latest', 40),
#  ('train', 40),
#  ('went', 40),
#  ('native', 39),
#  ('heritage', 39),
#  ('culture', 39),
#  ('organize', 39),
#  ('following', 39),
#  ('involved', 39),
#  ('respect', 39),
#  ('came', 39),
#  ('ly', 39),
#  ('court', 38),
#  ('equality', 38),
#  ('wasn', 38),
#  ('kill', 38),
#  ('louis', 38),
#  ('month', 38),
#  ('celebrate', 37),
#  ('wednesday', 37),
#  ('crimes', 37),
#  ('leave', 37),
#  ('attack', 37),
#  ('fired', 37),
#  ('20', 37),
#  ('24', 37),
#  ('ny', 37),
#  ('goals', 37),
#  ('instead', 36),
#  ('million', 36),
#  ('criminal', 36),
#  ('try', 36),
#  ('jesus', 36),
#  ('republican', 36),
#  ('families', 36),
#  ('pay', 36),
#  ('brown', 36),
#  ('terrorist', 36),
#  ('communities', 36),
#  ('businesses', 36),
#  ('order', 35),
#  ('future', 35),
#  ('lot', 35),
#  ('house', 35),
#  ('happen', 35),
#  ('martin', 35),
#  ('ones', 35),
#  ('week', 35),
#  ('officials', 35),
#  ('send', 35),
#  ('little', 35),
#  ('hell', 35),
#  ('charges', 35),
#  ('island', 35),
#  ('team', 35),
#  ('eric', 35),
#  ('fatally', 35),
#  ('girls', 35),
#  ('comment', 35),
#  ('charlotte', 35),
#  ('known', 34),
#  ('human', 34),
#  ('political', 34),
#  ('kind', 34),
#  ('happened', 34),
#  ('thousands', 34),
#  ('miss', 34),
#  ('marriage', 34),
#  ('problems', 34),
#  ('soldiers', 34),
#  ('army', 34),
#  ('read', 34),
#  ('ready', 34),
#  ('jobs', 34),
#  ('unarmed', 34),
#  ('weapon', 34),
#  ('breaking', 34),
#  ('blacklove', 34),
#  ('donald', 34),
#  ('failed', 34),
#  ('smith', 34),
#  ('powerful', 33),
#  ('making', 33),
#  ('killer', 33),
#  ('2015', 33),
#  ('realize', 33),
#  ('murder', 33),
#  ('told', 33),
#  ('boy', 33),
#  ('gray', 33),
#  ('isn', 33),
#  ('recently', 33),
#  ('left', 33),
#  ('break', 33),
#  ('simple', 33),
#  ('female', 33),
#  ('released', 33),
#  ('november', 33),
#  ('blackisbeautiful', 33),
#  ('blackgirlmagic', 33),
#  ('blackpower', 33),
#  ('whites', 32),
#  ('started', 32),
#  ('25', 32),
#  ('caught', 32),
#  ('using', 32),
#  ('possible', 32),
#  ('big', 32),
#  ('hope', 32),
#  ('word', 32),
#  ('finally', 32),
#  ('star', 32),
#  ('fatal', 32),
#  ('hall', 32),
#  ('comnviiliamsandkalvin', 32),
#  ('problack', 32),
#  ('empowerment', 32),
#  ('panafricanism', 32),
#  ('blacknationalism', 32),
#  ('africanandproud', 32),
#  ('amerikkka', 32),
#  ('unapologeticallyafrican', 32),
#  ('blacklnamerica', 32),
#  ('knowthyself', 32),
#  ('knowledgeofself', 32),
#  ('economicempowerment', 32),
#  ('whiteliesmatter', 32),
#  ('africanunity', 32),
#  ('paid', 31),
#  ('number', 31),
#  ('far', 31),
#  ('presidential', 31),
#  ('land', 31),
#  ('born', 31),
#  ('post', 31),
#  ('decided', 31),
#  ('continue', 31),
#  ('east', 31),
#  ('defend', 31),
#  ('diversity', 31),
#  ('monday', 31),
#  ('comments', 31),
#  ('brothers', 31),
#  ('petition', 31),
#  ('meetup', 31),
#  ('dope', 31),
#  ('blackempowerment', 31),
#  ('organization', 30),
#  ('question', 30),
#  ('add', 30),
#  ('2016', 30),
#  ('fellow', 30),
#  ('meet', 30),
#  ('ground', 30),
#  ('jones', 30),
#  ('wars', 30),
#  ('davis', 30),
#  ('fighting', 30),
#  ('says', 30),
#  ('freddie', 30),
#  ('luther', 30),
#  ('mom', 30),
#  ('thank', 30),
#  ('outside', 30),
#  ('chance', 30),
#  ('goal', 30),
#  ('democrat', 30),
#  ('infofacemusic', 30),
#  ('mexican', 30),
#  ('cases', 29),
#  ('changes', 29),
#  ('asked', 29),
#  ('happy', 29),
#  ('coming', 29),
#  ('policy', 29),
#  ('comes', 29),
#  ('hands', 29),
#  ('spent', 29),
#  ('stopped', 29),
#  ('health', 29),
#  ('talk', 29),
#  ('true', 29),
#  ('blue', 29),
#  ('attacks', 29),
#  ('shoot', 29),
#  ('forgotten', 29),
#  ('wife', 29),
#  ('protection', 29),
#  ('aiyana', 29),
#  ('westandtogether', 29),
#  ('integration', 29),
#  ('justiceorelse', 29),
#  ('street', 28),
#  ('unfortunately', 28),
#  ('tried', 28),
#  ('used', 28),
#  ('means', 28),
#  ('wants', 28),
#  ('carolina', 28),
#  ('saw', 28),
#  ('illegals', 28),
#  ('key', 28),
#  ('working', 28),
#  ('judge', 28),
#  ('needs', 28),
#  ('run', 28),
#  ('security', 28),
#  ('guys', 28),
#  ('driving', 28),
#  ('cost', 28),
#  ('16', 28),
#  ('31', 28),
#  ('hair', 28),
#  ('feb', 28),
#  ('given', 27),
#  ('experience', 27),
#  ('recent', 27),
#  ('19', 27),
#  ('daily', 27),
#  ('ago', 27),
#  ('pride', 27),
#  ('charged', 27),
#  ('saying', 27),
#  ('suspect', 27),
#  ('report', 27),
#  ('center', 27),
#  ('brought', 27),
#  ('brother', 27),
#  ('politicians', 27),
#  ('baltimore', 27),
#  ('beauty', 27),
#  ('kid', 27),
#  ('son', 27),
#  ('brave', 27),
#  ('saturday', 27),
#  ('peaceful', 27),
#  ('landing', 27),
#  ('study', 27),
#  ('jr', 27),
#  ('tea', 27),
#  ('blacklsbeautiful', 27),
#  ('passed', 26),
#  ('non', 26),
#  ('picture', 26),
#  ('welcome', 26),
#  ('service', 26),
#  ('start', 26),
#  ('kkk', 26),
#  ('dedicated', 26),
#  ('clear', 26),
#  ('wanted', 26),
#  ('act', 26),
#  ('percent', 26),
#  ('equal', 26),
#  ('california', 26),
#  ('seen', 26),
#  ('alive', 26),
#  ('point', 26),
#  ('constitution', 26),
#  ('west', 26),
#  ('different', 26),
#  ('open', 26),
#  ('photos', 26),
#  ('looks', 26),
#  ('roots', 26),
#  ('iraq', 26),
#  ('wrong', 26),
#  ('placed', 26),
#  ('veteran', 26),
#  ('enjoy', 26),
#  ('coach', 26),
#  ('staten', 26),
#  ('misty', 26),
#  ('washington', 25),
#  ('night', 25),
#  ('heard', 25),
#  ('demand', 25),
#  ('ask', 25),
#  ('especially', 25),
#  ('choose', 25),
#  ('ad', 25),
#  ('violent', 25),
#  ('months', 25),
#  ('gender', 25),
#  ('alabama', 25),
#  ('protests', 25),
#  ('safety', 25),
#  ('deal', 25),
#  ('medical', 25),
#  ('everyday', 25),
#  ('couple', 25),
#  ('youth', 25),
#  ('park', 25),
#  ('actions', 25),
#  ('teachers', 25),
#  ('created', 25),
#  ('dream', 25),
#  ('election', 25),
#  ('goes', 25),
#  ('urbrowser', 25),
#  ('unapologeticallyblack', 25),
#  ('unification', 25),
#  ('regrann', 25),
#  ('investigation', 24),
#  ('enforcement', 24),
#  ('late', 24),
#  ('later', 24),
#  ('moment', 24),
#  ('pro', 24),
#  ('classes', 24),
#  ('attorney', 24),
#  ('tuesday', 24),
#  ('message', 24),
#  ('near', 24),
#  ('treated', 24),
#  ('homeland', 24),
#  ('supporting', 24),
#  ('florida', 24),
#  ('threat', 24),
#  ('body', 24),
#  ('list', 24),
#  ('countries', 24),
#  ('refused', 24),
#  ('agree', 24),
#  ('oh', 24),
#  ('liberty', 24),
#  ('check', 24),
#  ('talking', 24),
#  ('philadelphia', 24),
#  ('pulled', 24),
#  ('shop', 24),
#  ('amazing', 24),
#  ('achieve', 24),
#  ('border', 24),
#  ('water', 24),
#  ('link', 24),
#  ('blackcommunity', 24),
#  ('pm', 24),
#  ('india', 24),
#  ('wakeup', 24),
#  ('breakingnews', 24),
#  ('control', 23),
#  ('birth', 23),
#  ('hold', 23),
#  ('authorities', 23),
#  ('shocking', 23),
#  ('skin', 23),
#  ('groups', 23),
#  ('june', 23),
#  ('excessive', 23),
#  ('deserve', 23),
#  ('straight', 23),
#  ('opinion', 23),
#  ('issue', 23),
#  ('congress', 23),
#  ('christian', 23),
#  ('guy', 23),
#  ('protesters', 23),
#  ('heroes', 23),
#  ('priority', 23),
#  ('serve', 23),
#  ('14', 23),
#  ('17', 23),
#  ('traffic', 23),
#  ('revealed', 23),
#  ('natural', 23),
#  ('ford', 23),
#  ('clark', 23),
#  ('jury', 23),
#  ('queens', 23),
#  ('scott', 23),
#  ('01', 23),
#  ('outrage', 22),
#  ('august', 22),
#  ('living', 22),
#  ('charleston', 22),
#  ('win', 22),
#  ('barack', 22),
#  ('photo', 22),
#  ('held', 22),
#  ('mean', 22),
#  ('yes', 22),
#  ('remove', 22),
#  ('religious', 22),
#  ('sexual', 22),
#  ('sex', 22),
#  ('led', 22),
#  ('grow', 22),
#  ('release', 22),
#  ('cell', 22),
#  ('christians', 22),
#  ('evidence', 22),
#  ('risk', 22),
#  ('store', 22),
#  ('terrorists', 22),
#  ('takes', 22),
#  ('lawsuit', 22),
#  ('sisters', 22),
#  ('blm', 22),
#  ('details', 22),
#  ('jamar', 22),
#  ('including', 21),
#  ('birthday', 21),
#  ('reasons', 21),
#  ('13', 21),
#  ('information', 21),
#  ('opened', 21),
#  ('remain', 21),
#  ('michael', 21),
#  ('allow', 21),
#  ('rate', 21),
#  ('past', 21),
#  ('slavery', 21),
#  ('afraid', 21),
#  ('plans', 21),
#  ('holding', 21),
#  ('decision', 21),
#  ('ban', 21),
#  ('action', 21),
#  ('buy', 21),
#  ('fast', 21),
#  ('growing', 21),
#  ('block', 21),
#  ('atlanta', 21),
#  ('turned', 21),
#  ('hatred', 21),
#  ('building', 21),
#  ('institutional', 21),
#  ('father', 21),
#  ('patriotic', 21),
#  ('2014', 21),
#  ('college', 21),
#  ('jason', 21),
#  ('memes', 21),
#  ('elections2016', 21),
#  ('extension', 21),
#  ('campbell', 21),
#  ('el', 21),
#  ('blackbeauty', 21),
#  ('simply', 20),
#  ('drugs', 20),
#  ('san', 20),
#  ('actually', 20),
#  ('activist', 20),
#  ('create', 20),
#  ('north', 20),
#  ('victim', 20),
#  ('awesome', 20),
#  ('islamophobia', 20),
#  ('criminals', 20),
#  ('sunday', 20),
#  ('getting', 20),
#  ('terrorism', 20),
#  ('course', 20),
#  ('lesbian', 20),
#  ('head', 20),
#  ('radical', 20),
#  ('raising', 20),
#  ('reports', 20),
#  ('answer', 20),
#  ('leaders', 20),
#  ('major', 20),
#  ('camera', 20),
#  ('search', 20),
#  ('warrant', 20),
#  ('wonder', 20),
#  ('islamic', 20),
#  ('return', 20),
#  ('beating', 20),
#  ('montgomery', 20),
#  ('fl', 20),
#  ('steve', 20),
#  ('stockley', 20),
#  ('wewillsurvive', 20),
#  ('local', 19),
#  ('greatest', 19),
#  ('leader', 19),
#  ('africa', 19),
#  ('slave', 19),
#  ('die', 19),
#  ('southern', 19),
#  ('image', 19),
#  ('hand', 19),
#  ('area', 19),
#  ('dangerous', 19),
#  ('teacher', 19),
#  ('shouldn', 19),
#  ('close', 19),
#  ('arms', 19),
#  ('began', 19),
#  ('performance', 19),
#  ('reality', 19),
#  ('100', 19),
#  ('lies', 19),
#  ('aren', 19),
#  ('age', 19),
#  ('custody', 19),
#  ('detroit', 19),
#  ('foreign', 19),
#  ('islam', 19),
#  ('license', 19),
#  ('duty', 19),
#  ('fix', 19),
#  ('values', 19),
#  ('filed', 19),
#  ('18', 19),
#  ('liberal', 19),
#  ('williamsandkalvin', 19),
#  ('mind', 19),
#  ('library', 19),
#  ('altonsterling', 19),
#  ('blackbusiness', 19),
#  ('deepening', 19),
#  ('ourcommunity', 19),
#  ('melaninqueen', 19),
#  ('ballet', 19),
#  ('couldn', 18),
#  ('able', 18),
#  ('ways', 18),
#  ('likely', 18),
#  ('inthe', 18),
#  ('showing', 18),
#  ('prove', 18),
#  ('soon', 18),
#  ('updates', 18),
#  ('streets', 18),
#  ('danger', 18),
#  ('small', 18),
#  ('guilty', 18),
#  ('plan', 18),
#  ('horrible', 18),
#  ('keeping', 18),
#  ('hero', 18),
#  ('gone', 18),
#  ('laws', 18),
#  ('feels', 18),
#  ('rape', 18),
#  ('food', 18),
#  ('mission', 18),
#  ('spread', 18),
#  ('loving', 18),
#  ('aliens', 18),
#  ('special', 18),
#  ('mark', 18),
#  ('billion', 18),
#  ('literally', 18),
#  ('light', 18),
#  ('mentally', 18),
#  ('looking', 18),
#  ('served', 18),
#  ('bbq', 18),
#  ('wanna', 18),
#  ('beyonce', 18),
#  ('apartment', 18),
#  ('dm', 18),
#  ('disturbing', 18),
#  ('success', 18),
#  ('flint', 18),
#  ('orlando', 18),
#  ('2017', 18),
#  ('dudeers', 18),
#  ('blackperfection', 18),
#  ('blackout', 18),
#  ('blackscience', 18),
#  ('accused', 17),
#  ('population', 17),
#  ('misconduct', 17),
#  ('hasn', 17),
#  ('january', 17),
#  ('26', 17),
#  ('forces', 17),
#  ('main', 17),
#  ('based', 17),
#  ('happens', 17),
#  ('patriot', 17),
#  ('art', 17),
#  ('wearing', 17),
#  ('boys', 17),
#  ('unite', 17),
#  ('fear', 17),
#  ('knows', 17),
#  ('morning', 17),
#  ('dear', 17),
#  ('budget', 17),
#  ('eye', 17),
#  ('residents', 17),
#  ('baby', 17),
#  ('developing', 17),
#  ('30', 17),
#  ('remind', 17),
#  ('isis', 17),
#  ('conservative', 17),
#  ('fine', 17),
#  ('step', 17),
#  ('lost', 17),
#  ('forever', 17),
#  ('sanders', 17),
#  ('centuries', 17),
#  ('friday', 17),
#  ('loehmann', 17),
#  ('lie', 17),
#  ('questions', 17),
#  ('efforts', 17),
#  ('tells', 17),
#  ('vets', 17),
#  ('beat', 17),
#  ('voted', 17),
#  ('syrian', 17),
#  ('spending', 17),
#  ('chanting', 17),
#  ('empower', 17),
#  ('source', 17),
#  ('tampa', 17),
#  ('pennsylvania', 17),
#  ('cajon', 17),
#  ('kings', 17),
#  ('terencecrutcher', 17),
#  ('knowledgeofselflsanationaiity', 17),
#  ('knowledge', 16),
#  ('pool', 16),
#  ('deputy', 16),
#  ('witnesses', 16),
#  ('reported', 16),
#  ('meeting', 16),
#  ('wake', 16),
#  ('50', 16),
#  ('administration', 16),
#  ('eyes', 16),
#  ('activists', 16),
#  ('single', 16),
#  ('lee', 16),
#  ('normal', 16),
#  ('employees', 16),
#  ('agenda', 16),
#  ('vehicle', 16),
#  ('creating', 16),
#  ('huge', 16),
#  ('received', 16),
#  ('suicide', 16),
#  ('rest', 16),
#  ('friendly', 16),
#  ('needed', 16),
#  ('colorado', 16),
#  ('thinks', 16),
#  ('posted', 16),
#  ('provide', 16),
#  ('telling', 16),
#  ('daughter', 16),
#  ('analysis', 16),
#  ('inside', 16),
#  ('assaulted', 16),
#  ('sandra', 16),
#  ('bland', 16),
#  ('denied', 16),
#  ('23', 16),
#  ('educated', 16),
#  ('dollars', 16),
#  ('website', 16),
#  ('member', 16),
#  ('ideas', 16),
#  ('disgusting', 16),
#  ('mass', 16),
#  ('bombing', 16),
#  ('abuse', 16),
#  ('drug', 16),
#  ('grand', 16),
#  ('counts', 16),
#  ('surprise', 16),
#  ('raping', 16),
#  ('sherry', 16),
#  ('tasted', 16),
#  ('mariners', 16),
#  ('leon', 16),
#  ('shirts', 16),
#  ('november8', 16),
#  ('excellence', 16),
#  ...]

# %%
y_black = ads['African American']

# %%
X_train_af, X_test_af, y_train_af, y_test_af = train_test_split(tf_mat, y_black, test_size=.3)

# %%
Af_boost = GradientBoostingClassifier().fit(X_train_af, y_train_af)
Af_boost
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
Af_boost.score(X_test_af, y_test_af)
# Out:
# 0.8113026819923371

# %% [markdown]
# ## Naive Bayes AF

# %%
af_bay = MultinomialNB(fit_prior=False).fit(X_train_af, y_train_af)

# %%
af_bay.score(X_test_af, y_test_af)
# Out:
# 0.8352490421455939

# %%
af_bay.fit(tf_mat, y_black)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=False)

# %%
af_pkl = open('web_app/data/af_bay.pkl', 'wb')
pickle.dump(af_bay, af_pkl)
af_pkl.close()

# %% [markdown]
# ## Grid Search

# %%
gb_grid_params = {'learning_rate': [0.1, 0.05, 0.02, 0.01],
              'max_depth': [4, 6, 8],
              'min_samples_leaf': [20, 50,100,150],
              'max_features': [1.0, 0.3, 0.1]}

# %%
grid_search_af = GridSearchCV(GradientBoostingClassifier(), gb_grid_params, n_jobs=-1, verbose=3)
grid_search_af.fit(X_train_af, y_train_af)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=50
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=50
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=50
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=100
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=50, score=0.7469135802469136, total=   3.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=50, score=0.7620221948212084, total=   3.5s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=50, score=0.7672413793103449, total=   3.6s
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=100, score=0.7250308261405672, total=   3.5s
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=100, score=0.7438423645320197, total=   3.5s
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, score=0.7753086419753087, total=   3.6s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=150
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=150
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=20
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, score=0.812807881773399, total=   3.7s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, score=0.8113440197287299, total=   3.7s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=50, score=0.770935960591133, total=   3.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=20, score=0.7728395061728395, total=   3.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=20, score=0.8101109741060419, total=   3.3s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=20, score=0.8140394088669951, total=   3.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=150, score=0.7012345679012346, total=   3.5s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=100, score=0.7271604938271605, total=   3.7s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=150, score=0.7266009852216748, total=   3.6s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=150, score=0.7139334155363748, total=   3.6s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=150
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    7.2s
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=150, score=0.7012345679012346, total=   2.5s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=150, score=0.7266009852216748, total=   2.7s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=150, score=0.7127003699136868, total=   2.8s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=100, score=0.725925925925926, total=   3.5s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=100, score=0.7475369458128078, total=   3.8s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=100, score=0.7262638717632552, total=   3.6s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=50, score=0.7506172839506173, total=   3.9s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.3, min_samples_leaf=50, score=0.7607891491985204, total=   4.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=20, score=0.8115763546798029, total=   1.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=20, score=0.8101109741060419, total=   1.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=20, score=0.7728395061728395, total=   1.3s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=100, score=0.7475369458128078, total=   0.8s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=100, score=0.7262638717632552, total=   0.8s
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=50, score=0.7795566502463054, total=   1.2s
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=150, score=0.7266009852216748, total=   0.6s
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=50, score=0.7444444444444445, total=   1.2s
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=150, score=0.7053020961775586, total=   0.6s
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=50, score=0.7583230579531443, total=   1.3s
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=100, score=0.7222222222222222, total=   0.8s
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=50
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.1, min_samples_leaf=150, score=0.6962962962962963, total=   0.5s
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=100, score=0.7413793103448276, total=   4.6s
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=50, score=0.7518518518518519, total=   4.6s
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=100, score=0.7250308261405672, total=   4.6s
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=50, score=0.7780517879161529, total=   4.8s
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=150
# [CV] learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=50, score=0.7857142857142857, total=   4.9s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=20, score=0.7814814814814814, total=   5.1s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=20, score=0.812577065351418, total=   5.2s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=20, score=0.8091133004926109, total=   5.4s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=150, score=0.7266009852216748, total=   4.2s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=150, score=0.7012345679012346, total=   4.1s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=150, score=0.7139334155363748, total=   4.2s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=6, max_features=1.0, min_samples_leaf=100, score=0.7320987654320987, total=   4.8s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=50, score=0.7721674876847291, total=   5.5s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=20, score=0.7777777777777778, total=   5.7s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=20, score=0.8177339901477833, total=   6.1s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=20, score=0.812577065351418, total=   6.0s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=150, score=0.7012345679012346, total=   2.4s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=100, score=0.7450738916256158, total=   4.5s
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=150, score=0.7253694581280788, total=   2.6s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=20
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=150, score=0.7090012330456227, total=   2.8s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=100, score=0.7250308261405672, total=   4.4s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=50, score=0.7469135802469136, total=   5.3s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=50, score=0.7768187422934648, total=   5.6s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.3, min_samples_leaf=100, score=0.7246913580246913, total=   4.0s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=100, score=0.7450738916256158, total=   1.0s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=20, score=0.7765432098765432, total=   2.1s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=100, score=0.7250308261405672, total=   0.9s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=20, score=0.8175092478421702, total=   2.2s
# [CV] learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=50, score=0.7783251231527094, total=   2.0s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=20, score=0.8201970443349754, total=   2.3s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=50, score=0.7706535141800247, total=   2.1s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=50, score=0.7358024691358025, total=   2.2s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=150, score=0.7192118226600985, total=   0.9s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=150, score=0.6962962962962963, total=   0.9s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=150, score=0.7127003699136868, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=6, max_features=0.1, min_samples_leaf=100, score=0.725925925925926, total=   1.3s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=100, score=0.7426108374384236, total=   5.3s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=100, score=0.7250308261405672, total=   5.3s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=50, score=0.754320987654321, total=   5.9s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=20, score=0.7802469135802469, total=   6.7s
# [CV] learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=50, score=0.7792848335388409, total=   6.1s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=50, score=0.7783251231527094, total=   6.1s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=20, score=0.8162762022194822, total=   7.0s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=20, score=0.8189655172413793, total=   7.1s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=150, score=0.7266009852216748, total=   4.2s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=150, score=0.7139334155363748, total=   4.2s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=150, score=0.7012345679012346, total=   4.1s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=8, max_features=1.0, min_samples_leaf=100, score=0.7320987654320987, total=   5.1s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=50, score=0.7844827586206896, total=   6.7s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=20, score=0.774074074074074, total=   7.3s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=20, score=0.8140394088669951, total=   7.6s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=20, score=0.8187422934648582, total=   7.6s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=100, score=0.7487684729064039, total=   4.5s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=100, score=0.7274969173859432, total=   4.3s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=150, score=0.7253694581280788, total=   2.2s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=150, score=0.7012345679012346, total=   2.1s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=150, score=0.7127003699136868, total=   2.3s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=50, score=0.7768187422934648, total=   6.7s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=50, score=0.7493827160493827, total=   6.3s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.3, min_samples_leaf=100, score=0.725925925925926, total=   3.8s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=20, score=0.8238916256157636, total=   2.6s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=100, score=0.7475369458128078, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=20, score=0.8224414303329223, total=   2.7s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=100, score=0.7262638717632552, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=150, score=0.7192118226600985, total=   0.6s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=100, score=0.7271604938271605, total=   0.9s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=150, score=0.7114673242909988, total=   0.6s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=50, score=0.7733990147783252, total=   2.3s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=50, score=0.7681874229346486, total=   2.3s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=150, score=0.7012345679012346, total=   0.6s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=20, score=0.7814814814814814, total=   2.7s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=50, score=0.7382716049382716, total=   2.1s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=50, score=0.7419753086419754, total=   4.1s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=20, score=0.7666666666666667, total=   4.3s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=50, score=0.770935960591133, total=   4.3s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=50, score=0.7558569667077681, total=   4.3s
# [CV] learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=20, score=0.8078817733990148, total=   4.5s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=100, score=0.7475369458128078, total=   4.2s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=100, score=0.7274969173859432, total=   4.2s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=20, score=0.7928483353884094, total=   4.6s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=50
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   51.3s
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=20, score=0.7641975308641975, total=   3.5s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=50, score=0.7684729064039408, total=   3.5s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=20, score=0.8054187192118226, total=   3.7s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=150, score=0.7012345679012346, total=   3.8s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=150, score=0.7266009852216748, total=   3.9s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=20, score=0.782983970406905, total=   3.7s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=100, score=0.7271604938271605, total=   4.0s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=4, max_features=1.0, min_samples_leaf=150, score=0.7114673242909988, total=   3.9s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=150, score=0.7253694581280788, total=   2.3s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=150, score=0.7012345679012346, total=   2.2s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=150, score=0.7127003699136868, total=   2.3s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=100, score=0.7250308261405672, total=   3.0s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=100, score=0.7271604938271605, total=   3.0s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=100, score=0.7475369458128078, total=   3.1s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=50, score=0.7358024691358025, total=   3.4s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.3, min_samples_leaf=50, score=0.752157829839704, total=   3.6s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=20, score=0.7866831072749692, total=   1.5s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=20, score=0.8066502463054187, total=   1.5s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=20, score=0.7604938271604939, total=   1.5s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=100, score=0.7475369458128078, total=   0.9s
# [CV] learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=100, score=0.7213316892725031, total=   1.0s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=150, score=0.7114673242909988, total=   0.6s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=150, score=0.7241379310344828, total=   0.7s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=50, score=0.770935960591133, total=   1.5s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=50, score=0.7333333333333333, total=   1.5s
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=50, score=0.7484586929716399, total=   1.5s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=50
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=100, score=0.7209876543209877, total=   1.0s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=4, max_features=0.1, min_samples_leaf=150, score=0.7, total=   0.7s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=100, score=0.7475369458128078, total=   5.3s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=50, score=0.7432098765432099, total=   5.6s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=100, score=0.7287299630086314, total=   5.4s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=50, score=0.7733990147783252, total=   6.0s
# [CV] learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=50, score=0.7632552404438965, total=   5.9s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=20, score=0.7716049382716049, total=   6.1s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=20, score=0.812807881773399, total=   6.4s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=20, score=0.8064118372379778, total=   6.4s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=150, score=0.7266009852216748, total=   4.1s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=150, score=0.7012345679012346, total=   3.9s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=150, score=0.7114673242909988, total=   4.1s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=6, max_features=1.0, min_samples_leaf=100, score=0.725925925925926, total=   4.6s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=50, score=0.7795566502463054, total=   4.7s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=20, score=0.7703703703703704, total=   4.9s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=20, score=0.8054187192118226, total=   5.2s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=20, score=0.8051787916152897, total=   5.2s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=100, score=0.7475369458128078, total=   3.3s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=150, score=0.7253694581280788, total=   2.0s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=150, score=0.7012345679012346, total=   1.9s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=100, score=0.7250308261405672, total=   3.2s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=150, score=0.7127003699136868, total=   2.2s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=50, score=0.7345679012345679, total=   4.1s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=50, score=0.7595561035758323, total=   4.3s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.3, min_samples_leaf=100, score=0.725925925925926, total=   3.2s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=100, score=0.7463054187192119, total=   0.8s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=50, score=0.7684729064039408, total=   1.6s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=20, score=0.7666666666666667, total=   1.7s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=50, score=0.7546239210850801, total=   1.6s
# [CV] learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=100, score=0.7237977805178791, total=   0.7s
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=20, score=0.8078817733990148, total=   1.8s
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=20
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=20, score=0.7965474722564735, total=   1.9s
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=150, score=0.7192118226600985, total=   0.6s
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=150, score=0.7012345679012346, total=   0.6s
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=150, score=0.7114673242909988, total=   0.6s
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=50
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=50, score=0.737037037037037, total=   1.7s
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=6, max_features=0.1, min_samples_leaf=100, score=0.7271604938271605, total=   0.8s
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=100, score=0.7274969173859432, total=   5.3s
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=100, score=0.7475369458128078, total=   5.3s
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=50, score=0.754320987654321, total=   5.9s
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=50, score=0.7758620689655172, total=   6.1s
# [CV] learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=20, score=0.7716049382716049, total=   6.6s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=50, score=0.7731196054254007, total=   6.1s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=20, score=0.813810110974106, total=   6.8s
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=20, score=0.8165024630541872, total=   6.8s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=20
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=150, score=0.7266009852216748, total=   3.8s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=150, score=0.7012345679012346, total=   3.8s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=150, score=0.7114673242909988, total=   4.0s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=8, max_features=1.0, min_samples_leaf=100, score=0.725925925925926, total=   4.6s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=50, score=0.7758620689655172, total=   6.2s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=20, score=0.7753086419753087, total=   6.7s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=20, score=0.8113440197287299, total=   7.0s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=20, score=0.8165024630541872, total=   7.1s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=100, score=0.7475369458128078, total=   3.9s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=100, score=0.7274969173859432, total=   4.0s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=150, score=0.7253694581280788, total=   2.6s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=150, score=0.7012345679012346, total=   2.7s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=150, score=0.7127003699136868, total=   2.8s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=50, score=0.7669543773119606, total=   6.8s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=50, score=0.737037037037037, total=   6.7s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.3, min_samples_leaf=100, score=0.725925925925926, total=   4.4s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=20, score=0.8152709359605911, total=   3.5s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=20, score=0.815043156596794, total=   3.5s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=100, score=0.7487684729064039, total=   1.1s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=100, score=0.7237977805178791, total=   1.1s
# [CV] learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=150, score=0.7241379310344828, total=   0.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=150, score=0.7016029593094945, total=   0.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=100, score=0.717283950617284, total=   1.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=150, score=0.7012345679012346, total=   0.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=50, score=0.737037037037037, total=   2.8s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=50, score=0.7758620689655172, total=   2.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=50, score=0.7533908754623921, total=   2.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.05, max_depth=8, max_features=0.1, min_samples_leaf=20, score=0.774074074074074, total=   3.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=20, score=0.7894088669950738, total=   4.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=50, score=0.7296296296296296, total=   4.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=20, score=0.762962962962963, total=   4.7s
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=100, score=0.7475369458128078, total=   4.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=150
# [CV] learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=100, score=0.7262638717632552, total=   4.2s
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=50, score=0.7348951911220715, total=   4.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=20, score=0.7694204685573366, total=   5.0s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=50, score=0.7561576354679803, total=   4.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=150, score=0.7253694581280788, total=   3.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=150, score=0.7012345679012346, total=   3.6s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, score=0.7530864197530864, total=   3.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=150, score=0.7114673242909988, total=   3.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, score=0.7549261083743842, total=   3.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, score=0.7832512315270936, total=   3.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, score=0.7743526510480888, total=   3.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=1.0, min_samples_leaf=100, score=0.7234567901234568, total=   3.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, score=0.7253694581280788, total=   2.0s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, score=0.7012345679012346, total=   1.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, score=0.7114673242909988, total=   2.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, score=0.7271604938271605, total=   2.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, score=0.7463054187192119, total=   2.8s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, score=0.7237977805178791, total=   2.8s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, score=0.7336621454993835, total=   3.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, score=0.7358024691358025, total=   3.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, score=0.7857142857142857, total=   1.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, score=0.7555555555555555, total=   1.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150
# ...
# [CV]  learning_rate=0.01, max_depth=4, max_features=0.1, min_samples_leaf=100, score=0.6942046855733662, total=   1.1s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=4, max_features=0.1, min_samples_leaf=150, score=0.7192118226600985, total=   0.7s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=4, max_features=0.1, min_samples_leaf=50, score=0.7536945812807881, total=   1.6s
# [CV]  learning_rate=0.01, max_depth=4, max_features=0.1, min_samples_leaf=150, score=0.6905055487053021, total=   0.8s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=20
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=4, max_features=0.1, min_samples_leaf=50, score=0.7308641975308642, total=   1.6s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=4, max_features=0.1, min_samples_leaf=50, score=0.7274969173859432, total=   1.6s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=4, max_features=0.1, min_samples_leaf=100, score=0.7123456790123457, total=   1.1s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=4, max_features=0.1, min_samples_leaf=150, score=0.7, total=   0.7s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=100, score=0.7253694581280788, total=   5.1s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=100, score=0.7114673242909988, total=   5.1s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=50, score=0.7283950617283951, total=   5.7s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=50, score=0.7561576354679803, total=   6.1s
# [CV] learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=50, score=0.7274969173859432, total=   6.1s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=20, score=0.7530864197530864, total=   6.2s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=20, score=0.7906403940886699, total=   6.5s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=20, score=0.7694204685573366, total=   6.6s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=150, score=0.7253694581280788, total=   3.6s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=150, score=0.7114673242909988, total=   3.8s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=150, score=0.7012345679012346, total=   3.6s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=6, max_features=1.0, min_samples_leaf=100, score=0.7012345679012346, total=   4.6s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=20, score=0.7807881773399015, total=   5.0s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=50, score=0.75, total=   4.5s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=20, score=0.7679012345679013, total=   4.8s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=20, score=0.7755856966707768, total=   5.0s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=100, score=0.7463054187192119, total=   3.3s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=100, score=0.720098643649815, total=   3.2s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=150, score=0.7012345679012346, total=   2.0s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=150, score=0.7241379310344828, total=   2.3s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=150, score=0.7114673242909988, total=   2.4s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=50, score=0.7373612823674476, total=   4.8s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=50, score=0.7320987654320987, total=   4.5s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.3, min_samples_leaf=100, score=0.7061728395061728, total=   3.4s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=100, score=0.7130541871921182, total=   0.9s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=20, score=0.7844827586206896, total=   2.2s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=50, score=0.7561576354679803, total=   1.8s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=20, score=0.7768187422934648, total=   2.2s
# [CV] learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=20, score=0.7604938271604939, total=   2.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=100, score=0.6794081381011098, total=   0.9s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=50, score=0.7435265104808878, total=   1.9s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=50, score=0.7296296296296296, total=   1.7s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=150, score=0.6995073891625616, total=   0.5s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=150, score=0.6851851851851852, total=   0.5s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=150, score=0.5536374845869297, total=   0.6s
# [CV]  learning_rate=0.01, max_depth=6, max_features=0.1, min_samples_leaf=100, score=0.6962962962962963, total=   0.9s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=100
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=100, score=0.7114673242909988, total=   4.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=100, score=0.7253694581280788, total=   4.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=50, score=0.7283950617283951, total=   5.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=50, score=0.7561576354679803, total=   5.6s
# [CV] learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=50, score=0.7274969173859432, total=   5.5s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=20, score=0.7881773399014779, total=   6.5s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=20, score=0.7506172839506173, total=   6.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=20, score=0.7718865598027127, total=   6.7s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=150, score=0.7253694581280788, total=   3.6s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=100, score=0.7012345679012346, total=   4.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=150, score=0.7012345679012346, total=   3.5s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=1.0, min_samples_leaf=150, score=0.7114673242909988, total=   3.7s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, score=0.7512315270935961, total=   5.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, score=0.7943349753694581, total=   6.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, score=0.7617283950617284, total=   5.8s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, score=0.7743526510480888, total=   6.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, score=0.7463054187192119, total=   3.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, score=0.7225647348951911, total=   3.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, score=0.7336621454993835, total=   5.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, score=0.7320987654320987, total=   5.0s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, score=0.7253694581280788, total=   2.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, score=0.7102342786683107, total=   2.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, score=0.7012345679012346, total=   1.9s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, score=0.725925925925926, total=   3.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, score=0.7179802955665024, total=   0.7s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, score=0.7955665024630542, total=   2.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, score=0.7731196054254007, total=   2.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, score=0.7003699136868065, total=   0.8s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, score=0.7641975308641975, total=   2.4s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, score=0.7019704433497537, total=   0.6s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, score=0.689272503082614, total=   0.6s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, score=0.7512315270935961, total=   1.9s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, score=0.6851851851851852, total=   0.8s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, score=0.7398273736128237, total=   1.9s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, score=0.6876543209876543, total=   0.4s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, score=0.7345679012345679, total=   1.8s
# [Parallel(n_jobs=-1)]: Done 432 out of 432 | elapsed:  3.0min finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'learning_rate': [0.1, 0.05, 0.02, 0.01], 'max_depth': [4, 6, 8], 'min_samples_leaf': [20, 50, 100, 150], 'max_features': [1.0, 0.3, 0.1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=3)

# %%
af_grad = grid_search_af.best_estimator_
af_grad
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-876d0a161f80> in <module>()
# ----> 1 af_grad = grid_search_af.best_estimator_
#       2 af_grad
#
# NameError: name 'grid_search_af' is not defined

# %%
af_grad.score(X_test_af, y_test_af)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ab97967fb1c4> in <module>()
# ----> 1 af_grad.score(X_test_af, y_test_af)
#
# NameError: name 'af_grad' is not defined

# %%
af_grad.fit(tf_mat, y_black)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=8,
#               max_features=0.1, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=20, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
#This is how to find important tf words
tf_array=np.array(tf.get_feature_names())
af_sorts = np.argsort(af_grad.feature_importances_)[::-1]
tf_array[af_sorts][:10]
# Out:
# array(['black', 'repost', 'com', 'woke', 'join', 'stop', 'organization',
#        'matters', 'free', 'african'], dtype='<U34')

# %%
af_feature_array=af_grad.feature_importances_

# %%
af_pkl = open('data/af_grad.pkl', 'wb')
pickle.dump(af_grad, af_pkl)
af_pkl.close()

# %% [markdown]
# ## Progressive

# %%
y_prog = ads['Progressive']

# %%
prog_grad = GradientBoostingClassifier(criterion='friedman_mse', init=None,
              learning_rate=0.1, loss='deviance', max_depth=8,
              max_features=0.1, max_leaf_nodes=None,
              min_impurity_decrease=0.0, min_impurity_split=None,
              min_samples_leaf=20, min_samples_split=2,
              min_weight_fraction_leaf=0.0, n_estimators=100,
              presort='auto', random_state=None, subsample=1.0, verbose=0,
              warm_start=False)

# %%
X_train_pr, X_test_pr, y_train_pr, y_test_pr = train_test_split(tf_mat, y_prog)

# %%
prog_grad.fit(X_train_pr, y_train_pr)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=8,
#               max_features=0.1, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=20, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
prog_grad.score(X_test_pr, y_test_pr)
# Out:
# 0.8724137931034482

# %%
prog_grad.

# %%
prog_pickle = open('data/prog_grad.pkl', 'wb')
pickle.dump(prog_grad, prog_pickle)
prog_pickle.close()

# %%
prog_sorts = np.argsort(prog_bay.feature_log_prob_)[1][::-1]
tf_array[prog_sorts][:10]
# Out:
# array(['repost', 'police', 'black', 'bm', 'brutality', 'man', 'video',
#        'cops', 'cop', 'join'], dtype='<U34')

# %%
prog_bay.predict_log_proba()
# Out:
# array([-0.69314718, -0.69314718])

# %% [markdown]
# ## Naive Bayes Progressive
# ### Grad Boost is better for progressive

# %%
prog_bay = MultinomialNB(fit_prior=False).fit(X_train_pr, y_train_pr)

# %%
prog_bay.score(X_test_pr, y_test_pr)
# Out:
# 0.8367816091954023

# %%
prog_pickle = open('web_app/data/prog_bay.pkl', 'wb')
pickle.dump(prog_bay, prog_pickle)
prog_pickle.close()

# %% [markdown]
# ## Getting important words from tfidf

# %%
#This is how to find important tf words
tf_array=np.array(tf.get_feature_names())
prog_sorts = np.argsort(prog_grad.feature_importances_)[::-1]
tf_array[prog_sorts][:10]
# Out:
# array(['repost', 'join', 'want', 'brutality', 'cop', 'http', 'bm',
#        'video', 'black', 'like'], dtype='<U34')

# %% [markdown]
# ## LatinX

# %%
latin_y = ads['Latinx']
lat_X_train, lat_X_test, lat_y_train, lat_y_test = train_test_split(tf_mat, latin_y, test_size=.3)

# %%
lat_bayes = MultinomialNB(fit_prior=False).fit(lat_X_train, lat_y_train)

# %%
lat_bayes.score(lat_X_test, lat_y_test)
# Out:
# 0.9224137931034483

# %%
lat_bayes.feature_log_prob_
# Out:
# array([[-9.87832114, -8.30317222, -9.87832114, ..., -9.72068145,
#         -9.87832114, -9.6141061 ],
#        [-9.34779403, -9.34779403, -9.34779403, ..., -9.34779403,
#         -9.34779403, -9.34779403]])

# %%
lat_bayes.fit(tf_mat, latin_y)
tf_mat.shape
# Out:
# (3477, 11174)

# %%
lat_path = open('web_app/data/lat_bay.pkl', 'wb')
pickle.dump(lat_bayes, lat_path)
lat_path.close()

# %%
lat_bayes.predict_proba
# Out:
# <bound method BaseNB.predict_proba of MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)>

# %%
#This is how to find important tf words
tf_array=np.array(tf.get_feature_names())
lat_sorts = np.argsort(lat_bayes.feature_log_prob_)[::]
tf_array[lat_sorts][:10]
# Out:
# array([['majorityminority', 'dual', 'scariest', ..., 'police', 'join',
#         'black'],
#        ['johnny', 'overturn', 'overwhelming', ..., 'mexico', 'like',
#         'mexican']], dtype='<U34')

# %% [markdown]
# ## Patriotism

# %%
y_pat = ads['Patriotism']

# %%
X_train_pat, X_test_pat, y_train_pat,y_test_pat = train_test_split(tf_mat, y_pat)

# %%
pat_bay = MultinomialNB(fit_prior=False).fit(X_train_pat, y_train_pat)

# %%
pat_bay.score(X_test_pat, y_test_pat)
# Out:
# 0.906896551724138

# %%
pat_bay.fit(tf_mat,y_pat)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=False)

# %%
pat_path= open('web_app/data/pat_bay.pkl', 'wb')
pickle.dump(pat_bay, pat_path)
pat_path.close()

# %%
pat_sorts = np.argsort(pat_bay.feature_log_prob_)[::]
tf_array[pat_sorts][:10]
# Out:
# array([['mimicking', 'mcmaster', 'meandmyflag', ..., 'police', 'join',
#         'black'],
#        ['00', 'nonchalantly', 'nonprofit', ..., 'homeland', 'heart',
#         'texas']], dtype='<U34')

# %%
pat_bay.class_count_
# Out:
# array([3296.,  181.])

# %%
lat_bayes.class_count_
# Out:
# array([3271.,  206.])
