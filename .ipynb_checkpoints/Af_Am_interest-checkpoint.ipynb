# %%
import numpy as np
import pandas as pd
from scripture.functions import *
from scripture.NLP_Pipe import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
af = get_interest_group('African American')

# %%
af[~af['conversion_rate'].isna() & ~af['ad_copy'].isna()]

# %%
af.columns

# %%
tf, count, tf_mat, count_mat, words = nlp_pipe(af)

# %%
words

# %%
count_mat

# %% [markdown]
# ## Gradient Boost regressor for conversion rate

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.grid_search import GridSearchCV
# Out:
# /Users/Matt/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/Matt/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
y = af[(~af['conversion_rate'].isna()) & (~af['ad_copy'].isna())]['conversion_rate']
X_train, X_test, y_train, y_test = train_test_split(count_mat, y, test_size=.3)

# %% [markdown]
# ## Grid Search

# %%
gb_grid_params = {
              'n_estimators': [60,100,150],
              'learning_rate':[0.02, 0.01],
              'max_depth': [4, 6, 8],
              'min_samples_leaf': [20, 50,100,150],
              'max_features': [.5, 0.3, 0.1] 
              }
gridsearch = GridSearchCV(GradientBoostingRegressor(), gb_grid_params, n_jobs=-1,verbose=3)

# %%
gridsearch.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=60
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=60
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=60
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=150
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=60, score=0.162658 -   0.9s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=60, score=0.189113 -   0.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=150
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=60, score=0.185997 -   0.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=0.190039 -   1.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=0.221162 -   1.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=0.212782 -   1.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=60, score=0.119218 -   0.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=60, score=0.134496 -   0.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=150, score=0.201469 -   2.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=60, score=0.130260 -   0.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=150, score=0.237238 -   2.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=100, score=0.142273 -   1.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=60, score=0.035071 -   0.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=100, score=0.162888 -   1.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=100, score=0.145619 -   1.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=60, score=0.022615 -   0.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=150, score=0.225709 -   2.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=60, score=0.017622 -   0.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=150
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    3.1s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=100, score=0.047437 -   0.8s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=150, score=0.172881 -   1.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=100, score=0.027493 -   0.8s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=60, score=0.025654 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=150, score=0.153704 -   1.9s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=100, score=0.014939 -   0.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=100
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=60, score=0.022470 -   0.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=50, n_estimators=150, score=0.152380 -   2.0s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=150, score=0.028110 -   1.0s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=60, score=0.009230 -   0.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=150, score=0.054772 -   1.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=100, score=0.035105 -   0.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=100, score=0.027200 -   0.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=100, score=0.006791 -   0.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=100, n_estimators=150, score=0.010362 -   1.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=150, score=0.043037 -   0.8s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=60, score=0.161705 -   0.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=60, score=0.184846 -   0.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=150, score=0.028773 -   0.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.5, min_samples_leaf=150, n_estimators=150, score=0.002382 -   0.9s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=60, score=0.179639 -   0.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=60, score=0.107205 -   0.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=100, score=0.197121 -   1.1s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=60, score=0.095308 -   0.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=100
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=100, score=0.218997 -   1.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=100, score=0.208285 -   1.0s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=60, score=0.097662 -   0.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=100, score=0.123852 -   0.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=100, score=0.138965 -   0.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=150, score=0.207945 -   1.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=150, score=0.232008 -   1.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=60, score=0.025368 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=20, n_estimators=150, score=0.224493 -   1.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=100, score=0.127044 -   0.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=60, score=0.018654 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=60, score=0.017476 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=100, score=0.022377 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=150, score=0.139802 -   0.9s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=100, score=0.037639 -   0.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=60
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=150, score=0.159455 -   1.0s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=100, score=0.017766 -   0.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=60, score=0.016751 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=60, score=0.008715 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=60, score=0.018719 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=50, n_estimators=150, score=0.143364 -   1.0s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=150, score=0.045779 -   0.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=150, score=0.025766 -   0.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=100, score=0.027002 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=100, score=0.022799 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=100, score=0.009191 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=60, score=0.136154 -   0.2s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=100, n_estimators=150, score=0.016254 -   0.7s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=100
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=60, score=0.148500 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=150, score=0.036780 -   0.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=60, score=0.149985 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=150, score=0.025934 -   0.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.3, min_samples_leaf=150, n_estimators=150, score=0.007442 -   0.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=100, score=0.174371 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=60, score=0.057565 -   0.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=60, score=0.055211 -   0.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=100, score=0.193684 -   0.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=100, score=0.185839 -   0.4s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=60, score=0.053293 -   0.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=100, score=0.067451 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=100, score=0.081634 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=100, score=0.083539 -   0.2s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=150, score=0.197650 -   0.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=60
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=60, score=0.012439 -   0.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=150, score=0.215274 -   0.5s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=60, score=0.006137 -   0.1s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=20, n_estimators=150, score=0.213257 -   0.6s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=100
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=60, score=0.009793 -   0.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=150, score=0.102726 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=150, score=0.093761 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=100, score=0.013735 -   0.2s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=100, score=0.011522 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=60
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=60, score=0.003269 -   0.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=50, n_estimators=150, score=0.097244 -   0.3s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=60, score=0.005858 -   0.1s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=150, score=0.013844 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=100, score=0.010474 -   0.2s
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=150, score=0.020210 -   0.2s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=60, score=0.004856 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=60
# [CV] learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=100, n_estimators=150, score=0.016646 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=100, score=0.012766 -   0.2s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=100, score=0.009796 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=60
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=100, score=0.005844 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=150, score=0.013844 -   0.2s
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=150, score=0.014815 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=4, max_features=0.1, min_samples_leaf=150, n_estimators=150, score=0.007036 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=60, score=0.180701 -   1.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=60, score=0.206459 -   1.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=60, score=0.199940 -   1.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=60, score=0.135408 -   0.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=60, score=0.115040 -   0.7s
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=0.204413 -   1.8s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=100
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=0.236343 -   1.8s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=0.227672 -   1.9s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   10.5s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=60, score=0.119783 -   0.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=150, score=0.216461 -   2.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=150, score=0.247743 -   2.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=100, score=0.139420 -   1.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=100, score=0.160562 -   1.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=100, score=0.148603 -   1.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=60, score=0.038306 -   0.5s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=60, score=0.023212 -   0.4s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=60, score=0.017563 -   0.6s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=20, n_estimators=150, score=0.242245 -   2.8s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=100, score=0.047522 -   0.8s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=150, score=0.172946 -   2.0s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=100, score=0.027240 -   0.8s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=100, score=0.014811 -   0.9s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=60, score=0.027649 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=150, score=0.151565 -   1.8s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=60, score=0.020143 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=60, score=0.009060 -   0.4s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=150, score=0.028163 -   1.0s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=100, score=0.039660 -   0.6s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=150, score=0.053799 -   1.4s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=100, score=0.027853 -   0.6s
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=50, n_estimators=150, score=0.149764 -   2.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=60
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=100, score=0.006621 -   0.6s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=100, n_estimators=150, score=0.009958 -   1.4s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=150, score=0.043037 -   0.9s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=60, score=0.175817 -   0.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=150, score=0.028773 -   0.8s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=60, score=0.206100 -   0.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=60, score=0.199868 -   0.8s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.5, min_samples_leaf=150, n_estimators=150, score=0.000608 -   0.9s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=60, score=0.102757 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=60, score=0.102892 -   0.4s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=100, score=0.208263 -   1.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=100, score=0.234821 -   1.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=60, score=0.098093 -   0.5s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=100, score=0.222952 -   1.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=100, score=0.141712 -   0.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=100, score=0.132731 -   0.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=60, score=0.026518 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=100, score=0.125177 -   0.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=60, score=0.016441 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=60, score=0.015863 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=150, score=0.249192 -   1.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=150, score=0.216832 -   1.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=20, n_estimators=150, score=0.242047 -   1.8s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=150, score=0.144474 -   0.9s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=150, score=0.162233 -   1.0s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=100, score=0.036266 -   0.4s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=100, score=0.022034 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=60, score=0.019457 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=100, score=0.018694 -   0.4s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=60, score=0.018200 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=50, n_estimators=150, score=0.144790 -   1.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=60, score=0.007925 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=150, score=0.044238 -   0.6s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=150, score=0.024567 -   0.5s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=100, score=0.028891 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=100, score=0.020576 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=100, score=0.009259 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=100, n_estimators=150, score=0.015343 -   0.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=60, score=0.156627 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=150, score=0.036377 -   0.4s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=60, score=0.165336 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=150, score=0.026567 -   0.5s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=60, score=0.178004 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.3, min_samples_leaf=150, n_estimators=150, score=0.008304 -   0.5s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=60, score=0.039051 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=60, score=0.027335 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=100, score=0.193170 -   0.5s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=100, score=0.207603 -   0.5s
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=60, score=0.047923 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=100
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=100, score=0.209724 -   0.5s
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=100, score=0.073341 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=150
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=100, score=0.062494 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=100, score=0.080637 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=60, score=0.008895 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=150, score=0.084494 -   0.3s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=60, score=0.007907 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=60, score=0.006421 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=150, score=0.078006 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=150, score=0.213979 -   0.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=100, score=0.010199 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=50, n_estimators=150, score=0.105940 -   0.3s
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=150, score=0.229064 -   0.7s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=60
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=20, n_estimators=150, score=0.228139 -   0.7s
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=100, score=0.008868 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=60
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=100, score=0.009665 -   0.2s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=60, score=0.004581 -   0.1s
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=60, score=0.005858 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=100
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=60, score=0.001586 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=100, score=0.010595 -   0.1s
# [CV] learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=150, score=0.018085 -   0.2s
# [CV] learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=150, score=0.017637 -   0.2s
# [CV] learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=100, n_estimators=150, score=0.014428 -   0.3s
# [CV] learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=100, score=0.010678 -   0.2s
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=100, score=0.004299 -   0.2s
# [CV] learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV] learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=150, score=0.011522 -   0.2s
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=150, score=0.013805 -   0.2s
# [CV] learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV] learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=6, max_features=0.1, min_samples_leaf=150, n_estimators=150, score=0.008556 -   0.2s
# [CV] learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=60, score=0.194841 -   1.3s
# [CV] learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=60, score=0.215738 -   1.3s
# [CV] learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.02, max_depth=8, max_features=0.5, min_samples_leaf=20, n_estimators=60, score=0.217669 -   1.3s
# ...
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.5, min_samples_leaf=150, n_estimators=150, score=0.009000 -   0.7s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=60, score=0.132222 -   0.8s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=60, score=0.151534 -   0.8s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=60, score=0.147501 -   0.8s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=60, score=0.074522 -   0.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=60, score=0.057430 -   0.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=100, score=0.173877 -   1.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=100, score=0.192626 -   1.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=60, score=0.059229 -   0.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=100, score=0.188040 -   1.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=100, score=0.099330 -   0.7s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=100, score=0.088740 -   0.6s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=100, score=0.100638 -   0.7s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=60, score=0.017039 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=60, score=0.006356 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=150, score=0.198340 -   2.0s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=150, score=0.125349 -   1.0s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=60, score=0.009468 -   0.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=150, score=0.223819 -   2.0s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=150, score=0.112508 -   1.0s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=20, n_estimators=150, score=0.221833 -   2.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=100, score=0.023238 -   0.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=50, n_estimators=150, score=0.113369 -   1.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=100, score=0.014821 -   0.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=60, score=0.008838 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=60, score=0.006876 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=100, score=0.012864 -   0.5s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=60, score=0.003354 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=100, score=0.019378 -   0.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=150, score=0.019105 -   0.6s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=150, score=0.033956 -   0.7s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=100, score=0.006650 -   0.3s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=100, score=0.012672 -   0.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=60
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=100, n_estimators=150, score=0.017279 -   0.7s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=150, score=0.025563 -   0.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=150, score=0.017876 -   0.4s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=60, score=0.104741 -   0.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=60, score=0.122104 -   0.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=60, score=0.116823 -   0.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.3, min_samples_leaf=150, n_estimators=150, score=0.009185 -   0.5s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=60, score=0.022425 -   0.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=60, score=0.017652 -   0.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=100, score=0.147851 -   0.5s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=100, score=0.163060 -   0.5s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=60, score=0.023169 -   0.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=100, score=0.044834 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=100, score=0.159844 -   0.5s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=100, score=0.034497 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=100, score=0.037714 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=60, score=0.004417 -   0.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=60, score=0.003010 -   0.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=150, score=0.067621 -   0.3s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=60, score=0.003062 -   0.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=100
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=150, score=0.048978 -   0.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=50, n_estimators=150, score=0.055717 -   0.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=150, score=0.181398 -   0.8s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=100, score=0.004612 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=100, score=0.005290 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=60
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=150, score=0.198651 -   0.8s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=100, score=0.006639 -   0.2s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=60
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=20, n_estimators=150, score=0.202076 -   0.8s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=60, score=0.005194 -   0.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=100
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=60, score=0.005290 -   0.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=60, score=0.000762 -   0.1s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=150, score=0.015444 -   0.3s
# [CV] learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=150
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=100, score=0.003248 -   0.2s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=150, score=0.005829 -   0.3s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=100, score=0.003010 -   0.2s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=100, score=0.002323 -   0.2s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=100, n_estimators=150, score=0.008961 -   0.3s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=150, score=0.010544 -   0.2s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=150, score=0.008837 -   0.2s
# [CV]  learning_rate=0.01, max_depth=8, max_features=0.1, min_samples_leaf=150, n_estimators=150, score=0.003673 -   0.2s
# [Parallel(n_jobs=-1)]: Done 648 out of 648 | elapsed:   54.6s finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'n_estimators': [60, 100, 150], 'learning_rate': [0.02, 0.01], 'max_depth': [4, 6, 8], 'min_samples_leaf': [20, 50, 100, 150], 'max_features': [0.5, 0.3, 0.1]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=3)

# %%
best = gridsearch.best_estimator_

# %%
best
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.02, loss='ls', max_depth=8, max_features=0.5,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=20,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=150, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
best.score(X_test, y_test)
# Out:
# 0.23241798259419133

# %%
best.fit(count_mat, y)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.02, loss='ls', max_depth=8, max_features=0.5,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=20,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=150, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %% [markdown]
# ## Out of the box classifier

# %%
grad = GradientBoostingRegressor(learning_rate=.1)
grad.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
grad.score(X_test, y_test)
# Out:
# 0.23843694114880287

# %% [markdown]
# ## Using the feature importances to find words that yield higher click efficiency

# %%
feats= best.feature_importances_
feats[3514]
# Out:
# 0.13810802225451552

# %%
feats[reverse]
# Out:
# array([0.13810802, 0.06082433, 0.04942887, ..., 0.        , 0.        ,
#        0.        ])

# %%
feature_array = np.array(count.get_feature_names())
reverse = np.argsort(feats)[::-1]

n = 10
top_n = feature_array[reverse][:n]
top_n
# Out:
# array(['join', 'black', 'follow', 'click', 'videos', 'community', 'rally',
#        'issues', 'repost', 'power'], dtype='<U32')

# %%
reverse
# Out:
# array([3514,  884, 2604, ..., 4644, 4645,    0])

# %%
feature_array[3514]
# Out:
# 'join'

# %%
#To get the text of an add with the given word
(af[(~af['conversion_rate'].isna()) & (~af['ad_copy'].isna())][count_mat[:,3514].todense()>0]).iloc[0,:]['ad_copy']
# Out:
# 'Philosophy of African-American activist Huey NewtonHuey Newton was an African-American political activist and a leader of generation of black, best known for founding the militant Black Panther Party in 1966. As a child, Newton experienced racial discrimination that influenced him to create the Black Panther Party as a voice of black people. His party grew up to a size of 5,000 full time party workers in 45 branches across America and inspired generation in North America to join the struggle against oppression. But he was shot to death in August 1989. '

# %%
af[(~af['conversion_rate'].isna()) & (~af['ad_copy'].isna())][count_mat[:,3514].todense()>0]\
.sort_values(by='conversion_rate', ascending=False)
# Out:
#       ad_clicks                                            ad_copy  \
# 2100          2  Join us to study your blackness and get the po...
# 1128         10  The system is wrong, we've got to be strong, A...
# 2205         81  I stopped watching tv for new, cus i can't tak...
# 1632       1098  Now after eight police officers were killed in...
# 2819        907  It's hard to express how simple and deep this ...
# 1448        241  Join us on June 18th to honor the memory of th...
# 2287         26  People are genuinely scared for their futures!...
# 1160          2  JOIN OURFeb. 1, she is arrested for car jackin...
# 1923        336  November 22 will mark the second anniversary o...
# 3374        194  Join us as we watch these lovely videos fillin...
# 2607       1205  We support the 2nd Amendment! Join us, if self...
# 1923                        ...
# 3374                        ...
# 2607                        ...
# 2195                        ...
# 751                         ...
# 916                         ...
# 9                           ...
# 2227                        ...
# 2235                        ...
# 2196                        ...
# 2101                        ...
# 762                         ...
# 2168                        ...
# 1711                        ...
# 2320                        ...
# 1710                        ...
# 1878                        ...
# 448                         ...
# 1715                        ...
# 1924                        ...
# 2321                        ...
# 3252                        ...
# ...                         ...
# 635                         ...
# 1969                        ...
# 968                         ...
# 527                         ...
# 526                         ...
# 1022                        ...
# 967                         ...
# 1116                        ...
# 518                         ...
# 1211                        ...
# 648                         ...
# 649                         ...
# 2283                        ...
# 1966                        ...
# 1064                        ...
# 2319                        ...
# 667                         ...
# 548                         ...
# 679                         ...
# 1024                        ...
# 608                         ...
# 2424                        ...
# 702                         ...
# 703                         ...
# 1021                        ...
# 997                         ...
# 969                         ...
# 726                         ...
# 2684                        ...
# 626                         ...
#
#       efficiency_impressions  \
# 2100                   13.46
# 1128                  205.56
# 2205                 1244.12
# 1632                  982.29
# 2819                 1704.32
# 1448                 1021.38
# 2287                  105.03
# 1160                  350.00
# 1923                  132.98
# 3374                  972.49
# 2607                  123.80
# 2195                  567.46
# 751                   188.27
# 916                   687.81
# 9                     229.78
# 2227                   85.32
# 2235                   21.63
# 2196                 1371.61
# 2101                  288.90
# 762                   146.70
# 2168                  249.00
# 1711                  364.31
# 2320                  198.43
# 1710                  315.16
# 1878                  248.58
# 448                   111.45
# 1715                  397.40
# 1924                  143.39
# 2321                  414.24
# 3252                  109.95
# ...                      ...
# 635                   189.01
# 1969                   43.72
# 968                    93.04
# 527                   356.90
# 526                   152.35
# 1022                  128.99
# 967                    70.54
# 1116                  150.00
# 518                   824.32
# 1211                  310.96
# 648                  1030.50
# 649                   793.23
# 2283                  200.00
# 1966                   38.16
# 1064                  205.88
# 2319                   12.41
# 667                      NaN
# 548                  1002.42
# 679                      NaN
# 1024                  152.38
# 608                   285.62
# 2424                  100.00
# 702                      NaN
# 703                      NaN
# 1021                  108.65
# 997                   757.38
# 969                   113.89
# 726                    83.33
# 2684                  207.44
# 626                      NaN
#
#                                      interest_expansion  \
# 2100     Pan-Africanism, Black history or Black (Color)
# 1128                              African American (US)
# 2205  Martin Luther King; Jr., African-American Civi...
# 1632                              African American (US)
# 2819  Martin Luther King, Jr., My Black is Beautiful...
# 1448                              African American (US)
# 2287  People who like BM, Friends of connections: Fr...
# 1160      Multicultural Affinity: African American (US)
# 1923  Black Power, Racial equality, Social justice,B...
# 3374  Martin Luther King, Jr., African-Americacultur...
# 2607  African-American Civil Rights Movem(1954-68), ...
# 2195  Martin Luther King, Jr., African-American Civi...
# 751       Multicultural Affinity: African American (US)
# 916   People who like Blacktivist, Friends of connec...
# 9     People who like Black Matters, Friends of conn...
# 2227  Martin Luther King, Jr., Pan-Africanism,Africa...
# 2235  Martin Luther King, Jr., National RiflAssociat...
# 2196  Martin Luther King, Jr., African-American Civi...
# 2101                                     Pan-Africanism
# 762                 Black Tea Patriots or BlackNews.com
# 2168             [Facebook]  News Feed on desktop computers or News Feed on...
# 1711             [Facebook]  News Feed on desktop computers, News Feed on m...
# 2320             [Facebook]  News Feed on desktop computers, News Feed on m...
# 1710             [Facebook]  News Feed on desktop computers, News Feed on m...
# 1878             [Facebook]  News Feed on desktop computers, News Feed on m...
# 448              [Facebook]  News Feed on desktop computers or News Feed on...
# 1715             [Facebook]  News Feed on desktop computers, News Feed on m...
# 1924             [Facebook]  News Feed on desktop computers or News Feed on...
# 2321             [Facebook]  News Feed on desktop computers, News Feed on m...
# 3252             [Facebook]  News Feed on desktop computers or News Feed on...
# ...                     ...                                                ...
# 635              [Facebook]  News Feed on desktop computers or News Feed on...
# 1969             [Facebook]  News Feed on desktop computers, News Feed on m...
# 968              [Facebook]  News Feed on desktop computers or News Feed on...
# 527             [Instagram]                                     Instagram Feed
# 526             [Instagram]                                     lnstagram Feed
# 1022             [Facebook]  News Feed on desktop computers or News Feed on...
# 967              [Facebook]  News Feed on desktop computers or News Feed on...
# 1116             [Facebook]  News Feed on desktop computers or News Feed on...
# 518             [Instagram]                                     Instagram Feed
# 1211            [Instagram]                                     Instagram Feed
# 648             [Instagram]                                     Instagram Feed
# 649             [Instagram]                                     Instagram Feed
# 2283             [Facebook]  News Feed on desktop computers or News Feed on...
# 1966             [Facebook]  News Feed on desktop computers, News Feed on m...
# 1064             [Facebook]  News Feed on desktop computers or News Feed on...
# 2319             [Facebook]  News Feed on desktop computers, News Feed on m...
# 667              [Facebook]  News Feed on desktop computers or News Feed on...
# 548             [Instagram]                                     Instagram Feed
# 679              [Facebook]  News Feed on desktop computers or News Feed on...
# 1024             [Facebook]  News Feed on desktop computers or News Feed on...
# 608             [Instagram]                                     Instagram Feed
# 2424             [Facebook]  News Feed on desktop computers, News Feed on m...
# 702              [Facebook]  News Feed on desktop computers or News Feed on...
# 703              [Facebook]  News Feed on desktop computers or News Feed on...
# 1021             [Facebook]  News Feed on desktop computers or News Feed on...
# 997             [Instagram]                                     lnstagram Feed
# 969              [Facebook]  News Feed on desktop computers or News Feed on...
# 726              [Facebook]  News Feed on desktop computers or News Feed on...
# 2684  [Facebook, Instagram]  News Feed on desktop computers, lnstagram Feed...
# 626              [Facebook]  News Feed on desktop computers or News Feed on...
#
# [131 rows x 24 columns]

# %%
count_mat[:,2604].todense()>0
# Out:
# matrix([[False],
#         [False],
#         [False],
#         ...,
#         [False],
#         [False],
#         [False]])

# %%
word_matrix_conversion(tf, X_train, y_train)
# Out:
# array(['join', 'black', 'follow', 'tofreedom', 'click', 'videos',
#        'blackexcellence', 'andtreats', 'absolutely', 'repost'],
#       dtype='<U32')

# %% [markdown]
# ## Graphing word importance

# %%
top_10, feat_imports = word_importances(count, best)

# %%
import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go

# %%
trace0 = go.Bar(
    x=top_10,
    y=feat_imports
)

data = [trace0]


py.iplot(data, filename = 'Af_am_word_importance', auto_open=False)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mhichar/12.embed" height="525px" width="100%"></iframe>
